# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_female=df[df['Sex'] == 'female'] 
df_male=df[df['Sex'] == 'male'] 
from IPython.display import display
display(df_female)
display(df_male)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_male['Age'].hist(bins = 20)
df_female['Age'].hist(bins = 20)
# Out:
# <Axes: >

# %%
df_female['Age'].hist(bins = 20)#df['Age'].hist())
# Out:
# <Axes: >

# %%
df_male['Age'].hist(bins = 20)
# Out:
# <Axes: >

# %%
print(df_female['Age'].mean())
print(df_male['Age'].mean())
# Out:
# 32.67613636363637
# 38.45178947368421

# %%
print(df_female['Age'].median())
print(df_male['Age'].median())
# Out:
# 32.25
# 37.0

# %%
print(df_female['Age'].mode())
print(df_male['Age'].mode())
# Out:
# 0    24.0
# Name: Age, dtype: float64
# 0    36.0
# Name: Age, dtype: float64

# %%
print(df_female['Age'].min())
print(df_male['Age'].min())
# Out:
# 2.0
# 0.92

# %%
print(df_female['Age'].max())
print(df_male['Age'].max())
# Out:
# 63.0
# 80.0

# %%
df_female['Age'].plot(kind='density') # kind = 'line', 'bar', 'hist', 'density', 'area', 'pie', 'scatter', 'hexbin'
# построить различные типы графиков
# Out:
# <Axes: ylabel='Density'>

# %%
df_male['Age'].plot(kind='density') # kind = 'line', 'bar', 'hist', 'density', 'area', 'pie', 'scatter', 'hexbin'
# построить различные типы графиков
# Out:
# <Axes: ylabel='Density'>

# %%
df_female['Age'].plot(kind='hist') # kind = 'line', 'bar', 'hist', 'density', 'area', 'pie', 'scatter', 'hexbin'
# построить различные типы графиков
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_male['Age'].plot(kind='hist') # kind = 'line', 'bar', 'hist', 'density', 'area', 'pie', 'scatter', 'hexbin'
# построить различные типы графиков
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_female['Age'].plot(kind='pie') # kind = 'line', 'bar', 'hist', 'density', 'area', 'pie', 'scatter', 'hexbin'
# построить различные типы графиков
# Out:
# <Axes: ylabel='Age'>

# %%
df_male['Age'].plot(kind='pie') # kind = 'line', 'bar', 'hist', 'density', 'area', 'pie', 'scatter', 'hexbin'
# построить различные типы графиков
# Out:
# <Axes: ylabel='Age'>

# %%
# разбейте исходную таблицу на 2: по полу пассажиров
# удалите пустые строки или заполните их соответствующими символами
# Построить гистограмму распределения пассажиров по возрасту
# Вычислите мин и макс, среднее, моду, медиану возраста пассажира каждого пола
# визуализировать возраст при помощи различных настроек метода plot

# %%
# изменение типов данных таблицы
# my_series = pd.to_numeric(my_series)
# s = s.astype(np.float16) # for series
#
# df.drop(columns=['col1', 'col2']) # drop columns
# df.drop([0, 1])# drop rows
